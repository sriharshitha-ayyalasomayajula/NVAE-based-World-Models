# %%
from models.vae import VAE

import torch

# %%
vae = VAE(3, 32)

vae.load_state_dict(torch.load('logs/vae/best.tar')["state_dict"])
# Out:
# <All keys matched successfully>

# %%
import numpy as np

a = np.load("/home/pagadalam/Santhosh/Workspace/Fake_Assignments/world-models/dataset/nvae_data/155656863.npz")["obs"]

import matplotlib.pyplot as plt

plt.imshow(a[2999])
